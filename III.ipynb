# %% [markdown]
# Start by running the line below.

# %%
# %run III_functions.ipynb

# %% [markdown]
# #### Utilities
#
# Insert the conditional utility matrix U(row | col) here, like this:
#
# ```
# U = np.array([[1,0,0],[1,0,1],[1,1,0]])
# ```

# %%
U = np.array([[1,0,0],[1,0,1],[1,1,0]])
print(U)
# Out:
# [[1 0 0]
#  [1 0 1]
#  [1 1 0]]

# %% [markdown]
# #### Act Probabilities
#
# Enter the act probability distribution here, like this:
# ```
# actprobs = np.array([1/3,1/3,1/3])
# ```

# %%
actprobs = np.array([1/3,1/3,1/3])
print(actprobs)
# Out:
# [0.33333333 0.33333333 0.33333333]

# %% [markdown]
# Check the rho-values for each of the acts (where rho(a) = max { I(a, b) | C(b) > o }) by running
# ```
# print(rhos(actprobs, U))
# ```

# %%
print(rhos(actprobs,U))
# Out:
# [0. 0. 0.]
